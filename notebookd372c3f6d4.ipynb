# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/adishnair/mdav-code/progress_report.md
# /kaggle/input/datasets/adishnair/mdav-code/main.py
# /kaggle/input/datasets/adishnair/mdav-code/requirements.txt
# /kaggle/input/datasets/adishnair/mdav-code/PROJECT_CONTEXT.md
# /kaggle/input/datasets/adishnair/mdav-code/setup_kaggle.py
# /kaggle/input/datasets/adishnair/mdav-code/tests/test_ocr_locator.py
# /kaggle/input/datasets/adishnair/mdav-code/tests/test_progress_tracker.py
# /kaggle/input/datasets/adishnair/mdav-code/tests/test_value_mutator.py
# /kaggle/input/datasets/adishnair/mdav-code/tests/test_ocr_verifier.py
# /kaggle/input/datasets/adishnair/mdav-code/tests/test_pipeline_contracts.py
# /kaggle/input/datasets/adishnair/mdav-code/tests/test_statistics.py
# /kaggle/input/datasets/adishnair/mdav-code/tests/test_setup_kaggle.py
# /kaggle/input/datasets/adishnair/mdav-code/docs/superpowers/plans/2026-06-30-value-region-localization.md
# /kaggle/input/datasets/adishnair/mdav-code/src/diffusers_generator.py
# ...

# %%
# Copy the code folder contents to your working directory
# !cp -r /kaggle/input/datasets/adishnair/mdav-code/* /kaggle/working/

# List the files in the working directory to verify
# !ls /kaggle/working/
# Out:
# docs	 progress_report.md  requirements.txt  src
# main.py  PROJECT_CONTEXT.md  setup_kaggle.py   tests

# %%
# Change the current directory to where your files are
# %cd /kaggle/working/

# Install all the required Python packages
# !pip install -r requirements.txt

# Run the Kaggle-specific setup script
# !python setup_kaggle.py
# Out:
# /kaggle/working
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 104.9 MB/s eta 0:00:0000:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 123.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 29.5 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.37.1
#     Uninstalling diffusers-0.37.1:
#       Successfully uninstalled diffusers-0.37.1
# ...

# %%
# 1. Force delete all huggingface caches
# !rm -rf /kaggle/working/.cache/huggingface/hub/*
# !rm -rf /root/.cache/huggingface/hub/*

# 2. Run setup again
# %cd /kaggle/working/
# !python setup_kaggle.py
# Out:
# /kaggle/working
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ...
# 2026-06-30 14:20:28,843 [INFO] HTTP Request: GET https://huggingface.co/api/whoami-v2 "HTTP/1.1 200 OK"
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# 2026-06-30 14:20:28,845 [WARNING] Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# 2026-06-30 14:20:28,845 [INFO] Caching diffusers/FLUX.1-Fill-dev-nf4 under /kaggle/working/.cache/huggingface
# 2026-06-30 14:20:28,913 [INFO] HTTP Request: GET https://huggingface.co/api/models/diffusers/FLUX.1-Fill-dev-nf4/revision/main "HTTP/1.1 200 OK"
# ...
# Fetching 10 files: 100%|█████████████████████| 10/10 [00:00<00:00, 21586.74it/s]
# ...

# %%
# 1. Remove the empty datasets folder if the script accidentally created one
# !rm -rf /kaggle/working/datasets

# 2. Create a symbolic link pointing to your actual data
# !ln -s /kaggle/input/mdav-datasets/datasets /kaggle/working/datasets

# %%
# !python main.py --output-dir ./outputs
# Out:
# 2026-06-30 14:28:44 [INFO] aiforge — Starting AIForge Document Forgery Dataset Pipeline...
# 2026-06-30 14:28:44 [INFO] aiforge — Config: seed=42 limit=None datasets=['CORD', 'FUNSD', 'SROIE', 'XFUND'] variants=2 shard=0/1
# 2026-06-30 14:28:44 [WARNING] src.cord_loader — CORD split 'train' annotation dir not found: /kaggle/working/datasets/CORD/train/annotations
# 2026-06-30 14:28:44 [WARNING] src.cord_loader — CORD split 'validation' annotation dir not found: /kaggle/working/datasets/CORD/validation/annotations
# 2026-06-30 14:28:44 [WARNING] src.cord_loader — CORD split 'test' annotation dir not found: /kaggle/working/datasets/CORD/test/annotations
# 2026-06-30 14:28:44 [INFO] src.cord_loader — CORD: loaded 0 documents total
# 2026-06-30 14:28:44 [INFO] src.dataset_loader — Loaded 0 CORD documents
# 2026-06-30 14:28:44 [WARNING] src.funsd_loader — FUNSD split 'train' annotation dir not found: /kaggle/working/datasets/FUNSD/train/annotations
# ...

# %%
# 1. Delete the broken shortcut from our previous attempt
# !rm -rf /kaggle/working/datasets

# 2. Create a fresh, empty directory
# !mkdir -p /kaggle/working/datasets

# 3. Automatically find the exact dataset path and copy the files over
# !DATA_DIR=$(dirname $(find /kaggle/input -type d -name "CORD" | head -n 1)); echo "Found data at: $DATA_DIR"; cp -r "$DATA_DIR"/* /kaggle/working/datasets/

# 4. Verify the folders are there
# !ls /kaggle/working/datasets/
# Out:
# Found data at: /kaggle/input/datasets/adishnair/mdav-datasets/datasets
# CORD  FUNSD  SROIE  XFUND

# %%
# !python main.py --output-dir ./outputs
# Out:
# 2026-06-30 14:45:23 [INFO] aiforge — Starting AIForge Document Forgery Dataset Pipeline...
# 2026-06-30 14:45:23 [INFO] aiforge — Config: seed=42 limit=None datasets=['CORD', 'FUNSD', 'SROIE', 'XFUND'] variants=2 shard=0/1
# 2026-06-30 14:45:23 [INFO] src.cord_loader — CORD train: found 800 annotation files
# 2026-06-30 14:45:24 [INFO] src.cord_loader — CORD validation: found 100 annotation files
# 2026-06-30 14:45:24 [INFO] src.cord_loader — CORD test: found 100 annotation files
# 2026-06-30 14:45:24 [INFO] src.cord_loader — CORD: loaded 1000 documents total
# 2026-06-30 14:45:24 [INFO] src.dataset_loader — Loaded 1000 CORD documents
# 2026-06-30 14:45:24 [INFO] src.funsd_loader — FUNSD train: found 149 annotation files
# 2026-06-30 14:45:24 [INFO] src.funsd_loader — FUNSD test: found 50 annotation files
# 2026-06-30 14:45:24 [INFO] src.funsd_loader — FUNSD: loaded 199 documents total
# 2026-06-30 14:45:24 [INFO] src.dataset_loader — Loaded 199 FUNSD documents
# ...
